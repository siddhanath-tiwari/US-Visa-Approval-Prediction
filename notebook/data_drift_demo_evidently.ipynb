# %% [markdown]
# Data Drift Dashboard for Boston Dataset

# %%
# !pip install evidently==0.2.8
# Out:
# Collecting evidently==0.2.8
#   Using cached evidently-0.2.8-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: plotly>=5.5.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (5.20.0)
# Collecting statsmodels>=0.12.2 (from evidently==0.2.8)
#   Using cached statsmodels-0.14.2-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (1.4.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (2.2.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (1.26.4)
# Requirement already satisfied: nltk>=3.6.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (3.8.1)
# Requirement already satisfied: scipy>=1.5.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (1.13.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (2.31.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (6.0.1)
# Requirement already satisfied: pydantic<2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from evidently==0.2.8) (1.10.15)
# Requirement already satisfied: click in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.6.7->evidently==0.2.8) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.6.7->evidently==0.2.8) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.6.7->evidently==0.2.8) (2024.4.28)
# Requirement already satisfied: tqdm in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.6.7->evidently==0.2.8) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.5->evidently==0.2.8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.5->evidently==0.2.8) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.5->evidently==0.2.8) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from plotly>=5.5.0->evidently==0.2.8) (8.2.3)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from plotly>=5.5.0->evidently==0.2.8) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<2->evidently==0.2.8) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->evidently==0.2.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->evidently==0.2.8) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->evidently==0.2.8) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->evidently==0.2.8) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.24.0->evidently==0.2.8) (3.4.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.12.2->evidently==0.2.8)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: six in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.12.2->evidently==0.2.8) (1.16.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from click->nltk>=3.6.7->evidently==0.2.8) (0.4.6)
# Using cached evidently-0.2.8-py3-none-any.whl (12.1 MB)
# Using cached statsmodels-0.14.2-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels, evidently
# Successfully installed evidently-0.2.8 patsy-0.5.6 statsmodels-0.14.2
# DEPRECATION: Loading egg at c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\heart-0.0.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\medical_chatbot-0.0.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\mlproject-0.0.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\mlproject-0.0.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\siddhanth-0.0.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\us_visa-0.0.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import pandas as pd

from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab

from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 from evidently.dashboard import Dashboard
#       4 from evidently.tabs import DataDriftTab, CatTargetDriftTab
#       6 from evidently.model_profile import Profile
#
# ModuleNotFoundError: No module named 'evidently.dashboard'

# %%
pip install evidently
# Out:
# Requirement already satisfied: evidently in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (0.4.22)
# Requirement already satisfied: plotly>=5.10.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (5.22.0)
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (0.14.1)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (1.3.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas[parquet]>=1.3.5->evidently) (2.0.3)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (1.24.4)
# Requirement already satisfied: nltk>=3.6.7 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (3.8.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (1.10.1)
# Requirement already satisfied: requests>=2.31.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (2.31.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (6.0.1)
# Requirement already satisfied: pydantic>=1.10.13 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (2.7.1)
# Requirement already satisfied: litestar>=2.8.3 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (2.8.3)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (0.9.0)
# Requirement already satisfied: uvicorn>=0.22.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.29.0)
# Requirement already satisfied: watchdog>=3 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (4.0.0)
# Requirement already satisfied: typer>=0.3 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (0.12.3)
# Requirement already satisfied: rich>=13 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (13.7.1)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (0.0.8)
# Requirement already satisfied: dynaconf>=3.2.4 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (3.2.5)
# Requirement already satisfied: certifi>=2023.07.22 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (2024.2.2)
# Requirement already satisfied: urllib3>=1.26.18 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (2.2.1)
# Requirement already satisfied: fsspec>=2024.2.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (2024.5.0)
# Requirement already satisfied: ujson>=5.4.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (5.10.0)
# Requirement already satisfied: appdirs in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from iterative-telemetry>=0.0.5->evidently) (1.4.4)
# Requirement already satisfied: filelock in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from iterative-telemetry>=0.0.5->evidently) (3.14.0)
# Requirement already satisfied: distro in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from iterative-telemetry>=0.0.5->evidently) (1.9.0)
# Requirement already satisfied: anyio>=3 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (4.3.0)
# Requirement already satisfied: click in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (8.1.7)
# Requirement already satisfied: exceptiongroup in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (1.2.1)
# Requirement already satisfied: httpx>=0.22 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (0.27.0)
# Requirement already satisfied: importlib-metadata in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (7.1.0)
# Requirement already satisfied: importlib-resources>=5.12.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (6.4.0)
# Requirement already satisfied: msgspec>=0.18.2 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (0.18.6)
# Requirement already satisfied: multidict>=6.0.2 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (6.0.5)
# Requirement already satisfied: polyfactory>=2.6.3 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (2.16.0)
# Requirement already satisfied: rich-click in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (1.8.2)
# Requirement already satisfied: typing-extensions in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (4.11.0)
# Requirement already satisfied: joblib in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from nltk>=3.6.7->evidently) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from nltk>=3.6.7->evidently) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from nltk>=3.6.7->evidently) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2024.1)
# Requirement already satisfied: pyarrow>=7.0.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas[parquet]>=1.3.5->evidently) (16.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from plotly>=5.10.0->evidently) (8.3.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from plotly>=5.10.0->evidently) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pydantic>=1.10.13->evidently) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pydantic>=1.10.13->evidently) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from requests>=2.31.0->evidently) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from requests>=2.31.0->evidently) (3.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from rich>=13->evidently) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from rich>=13->evidently) (2.18.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from scikit-learn>=1.0.1->evidently) (3.5.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from statsmodels>=0.12.2->evidently) (0.5.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from typer>=0.3->evidently) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from typing-inspect>=0.9.0->evidently) (1.0.0)
# Requirement already satisfied: h11>=0.8 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn>=0.22.0->uvicorn[standard]>=0.22.0->evidently) (0.14.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.4.6)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (12.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from anyio>=3->litestar>=2.8.3->evidently) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from httpx>=0.22->litestar>=2.8.3->evidently) (1.0.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from importlib-resources>=5.12.0->litestar>=2.8.3->evidently) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently) (0.1.2)
# Requirement already satisfied: six in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.12.2->evidently) (1.16.0)
# Requirement already satisfied: faker in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently) (25.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install evidently 0.1.22.dev0
# Out:
# Requirement already satisfied: evidently in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (0.4.22)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement 0.1.22.dev0 (from versions: none)
# ERROR: No matching distribution found for 0.1.22.dev0

# %%
pip install evidently
# Out:
# Collecting evidently
#   Downloading evidently-0.4.22-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: plotly>=5.10.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (5.22.0)
# Collecting statsmodels>=0.12.2 (from evidently)
#   Using cached statsmodels-0.14.1-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (1.3.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas[parquet]>=1.3.5->evidently) (2.0.3)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (1.24.4)
# Collecting nltk>=3.6.7 (from evidently)
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from evidently) (1.10.1)
# Collecting requests>=2.31.0 (from evidently)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting PyYAML>=5.4 (from evidently)
#   Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
# Collecting pydantic>=1.10.13 (from evidently)
#   Using cached pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
# Collecting litestar>=2.8.3 (from evidently)
#   Downloading litestar-2.8.3-py3-none-any.whl.metadata (99 kB)
#      ---------------------------------------- 0.0/99.3 kB ? eta -:--:--
#      ---------------------------------------- 99.3/99.3 kB 1.9 MB/s eta 0:00:00
# Collecting typing-inspect>=0.9.0 (from evidently)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting uvicorn>=0.22.0 (from uvicorn[standard]>=0.22.0->evidently)
#   Using cached uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting watchdog>=3 (from evidently)
#   Using cached watchdog-4.0.0-py3-none-win_amd64.whl.metadata (37 kB)
# Collecting typer>=0.3 (from evidently)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting rich>=13 (from evidently)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting iterative-telemetry>=0.0.5 (from evidently)
#   Downloading iterative_telemetry-0.0.8-py3-none-any.whl.metadata (4.1 kB)
# Collecting dynaconf>=3.2.4 (from evidently)
#   Downloading dynaconf-3.2.5-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting certifi>=2023.07.22 (from evidently)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting urllib3>=1.26.18 (from evidently)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting fsspec>=2024.2.0 (from evidently)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting ujson>=5.4.0 (from evidently)
#   Downloading ujson-5.10.0-cp38-cp38-win_amd64.whl.metadata (9.5 kB)
# Collecting appdirs (from iterative-telemetry>=0.0.5->evidently)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting filelock (from iterative-telemetry>=0.0.5->evidently)
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting distro (from iterative-telemetry>=0.0.5->evidently)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting anyio>=3 (from litestar>=2.8.3->evidently)
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting click (from litestar>=2.8.3->evidently)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting exceptiongroup (from litestar>=2.8.3->evidently)
#   Using cached exceptiongroup-1.2.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting httpx>=0.22 (from litestar>=2.8.3->evidently)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: importlib-metadata in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (7.1.0)
# Requirement already satisfied: importlib-resources>=5.12.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (6.4.0)
# Collecting msgspec>=0.18.2 (from litestar>=2.8.3->evidently)
#   Downloading msgspec-0.18.6-cp38-cp38-win_amd64.whl.metadata (7.1 kB)
# Collecting multidict>=6.0.2 (from litestar>=2.8.3->evidently)
#   Using cached multidict-6.0.5-cp38-cp38-win_amd64.whl.metadata (4.3 kB)
# Collecting polyfactory>=2.6.3 (from litestar>=2.8.3->evidently)
#   Downloading polyfactory-2.16.0-py3-none-any.whl.metadata (27 kB)
# Collecting rich-click (from litestar>=2.8.3->evidently)
#   Downloading rich_click-1.8.2-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: typing-extensions in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from litestar>=2.8.3->evidently) (4.11.0)
# Requirement already satisfied: joblib in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from nltk>=3.6.7->evidently) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk>=3.6.7->evidently)
#   Downloading regex-2024.5.15-cp38-cp38-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB ? eta 0:00:00
# Collecting tqdm (from nltk>=3.6.7->evidently)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2024.1)
# Collecting pyarrow>=7.0.0 (from pandas[parquet]>=1.3.5->evidently)
#   Downloading pyarrow-16.1.0-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from plotly>=5.10.0->evidently) (8.3.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from plotly>=5.10.0->evidently) (24.0)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.10.13->evidently)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic>=1.10.13->evidently)
#   Using cached pydantic_core-2.18.2-cp38-none-win_amd64.whl.metadata (6.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31.0->evidently)
#   Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31.0->evidently)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13->evidently)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from rich>=13->evidently) (2.18.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from scikit-learn>=1.0.1->evidently) (3.5.0)
# Collecting patsy>=0.5.4 (from statsmodels>=0.12.2->evidently)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.3->evidently)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.9.0->evidently)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting h11>=0.8 (from uvicorn>=0.22.0->uvicorn[standard]>=0.22.0->evidently)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: colorama>=0.4 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.4.6)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.22.0->evidently)
#   Downloading httptools-0.6.1-cp38-cp38-win_amd64.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.22.0->evidently)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.22.0->evidently)
#   Downloading watchfiles-0.21.0-cp38-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.22.0->evidently)
#   Downloading websockets-12.0-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Collecting sniffio>=1.1 (from anyio>=3->litestar>=2.8.3->evidently)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting httpcore==1.* (from httpx>=0.22->litestar>=2.8.3->evidently)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from importlib-resources>=5.12.0->litestar>=2.8.3->evidently) (3.17.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13->evidently)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six in c:\users\hp\appdata\local\anaconda3\envs\visa\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.12.2->evidently) (1.16.0)
# Collecting faker (from polyfactory>=2.6.3->litestar>=2.8.3->evidently)
#   Downloading Faker-25.2.0-py3-none-any.whl.metadata (15 kB)
# Downloading evidently-0.4.22-py3-none-any.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.7/3.4 MB 4.9 MB/s eta 0:00:01
#    ------------ --------------------------- 1.1/3.4 MB 4.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.3/3.4 MB 3.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.5/3.4 MB 3.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.7/3.4 MB 2.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.9/3.4 MB 2.8 MB/s eta 0:00:01
#    ------------------------- -------------- 2.2/3.4 MB 2.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.5/3.4 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.0/3.4 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 3.1 MB/s eta 0:00:00
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Downloading dynaconf-3.2.5-py2.py3-none-any.whl (230 kB)
#    ---------------------------------------- 0.0/230.8 kB ? eta -:--:--
#    --------------------------------------- 230.8/230.8 kB 14.7 MB/s eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ---------------------------------------- 0.0/316.1 kB ? eta -:--:--
#    --------------------------------------- 316.1/316.1 kB 19.1 MB/s eta 0:00:00
# Downloading iterative_telemetry-0.0.8-py3-none-any.whl (10 kB)
# Downloading litestar-2.8.3-py3-none-any.whl (523 kB)
#    ---------------------------------------- 0.0/524.0 kB ? eta -:--:--
#    --------------------------------------- 524.0/524.0 kB 16.6 MB/s eta 0:00:00
# Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Using cached pydantic-2.7.1-py3-none-any.whl (409 kB)
# Using cached pydantic_core-2.18.2-cp38-none-win_amd64.whl (1.9 MB)
# Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl (157 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached statsmodels-0.14.1-cp38-cp38-win_amd64.whl (10.0 MB)
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.2 kB ? eta -:--:--
#    ---------------------------------------- 47.2/47.2 kB 2.3 MB/s eta 0:00:00
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading ujson-5.10.0-cp38-cp38-win_amd64.whl (42 kB)
#    ---------------------------------------- 0.0/42.1 kB ? eta -:--:--
#    ---------------------------------------- 42.1/42.1 kB 2.1 MB/s eta 0:00:00
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached uvicorn-0.29.0-py3-none-any.whl (60 kB)
# Using cached watchdog-4.0.0-py3-none-win_amd64.whl (82 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl (99 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading httptools-0.6.1-cp38-cp38-win_amd64.whl (60 kB)
#    ---------------------------------------- 0.0/60.2 kB ? eta -:--:--
#    ---------------------------------------- 60.2/60.2 kB ? eta 0:00:00
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading msgspec-0.18.6-cp38-cp38-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.7 kB ? eta -:--:--
#    --------------------------------------- 187.7/187.7 kB 11.1 MB/s eta 0:00:00
# Using cached multidict-6.0.5-cp38-cp38-win_amd64.whl (28 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading polyfactory-2.16.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.4 kB ? eta -:--:--
#    ---------------------------------------- 57.4/57.4 kB 1.5 MB/s eta 0:00:00
# Downloading pyarrow-16.1.0-cp38-cp38-win_amd64.whl (25.9 MB)
#    ---------------------------------------- 0.0/25.9 MB ? eta -:--:--
#    -- ------------------------------------- 1.4/25.9 MB 17.6 MB/s eta 0:00:02
#    -- ------------------------------------- 1.6/25.9 MB 10.0 MB/s eta 0:00:03
#    --- ------------------------------------ 2.0/25.9 MB 6.2 MB/s eta 0:00:04
#    --- ------------------------------------ 2.4/25.9 MB 5.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.7/25.9 MB 5.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.0/25.9 MB 5.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.4/25.9 MB 5.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.6/25.9 MB 4.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.7/25.9 MB 4.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.8/25.9 MB 4.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.9/25.9 MB 4.0 MB/s eta 0:00:06
#    ------ --------------------------------- 4.0/25.9 MB 3.8 MB/s eta 0:00:06
#    ------ --------------------------------- 4.1/25.9 MB 3.7 MB/s eta 0:00:06
#    ------ --------------------------------- 4.3/25.9 MB 3.6 MB/s eta 0:00:07
#    ------ --------------------------------- 4.4/25.9 MB 3.6 MB/s eta 0:00:07
#    ------- -------------------------------- 4.7/25.9 MB 3.4 MB/s eta 0:00:07
#    ------- -------------------------------- 5.0/25.9 MB 3.4 MB/s eta 0:00:07
#    -------- ------------------------------- 5.3/25.9 MB 3.4 MB/s eta 0:00:07
#    -------- ------------------------------- 5.6/25.9 MB 3.4 MB/s eta 0:00:06
#    --------- ------------------------------ 5.8/25.9 MB 3.5 MB/s eta 0:00:06
#    --------- ------------------------------ 6.0/25.9 MB 3.5 MB/s eta 0:00:06
#    --------- ------------------------------ 6.3/25.9 MB 3.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.8/25.9 MB 3.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 7.0/25.9 MB 3.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.3/25.9 MB 3.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.6/25.9 MB 3.5 MB/s eta 0:00:06
#    ------------ --------------------------- 8.1/25.9 MB 3.6 MB/s eta 0:00:05
#    -------------- ------------------------- 9.5/25.9 MB 3.7 MB/s eta 0:00:05
#    --------------- ------------------------ 9.9/25.9 MB 3.7 MB/s eta 0:00:05
#    --------------- ------------------------ 10.2/25.9 MB 3.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.6/25.9 MB 3.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.1/25.9 MB 3.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.4/25.9 MB 3.4 MB/s eta 0:00:05
#    ------------------ --------------------- 11.9/25.9 MB 3.5 MB/s eta 0:00:04
#    ------------------ --------------------- 12.2/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------- -------------------- 12.6/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------- -------------------- 12.9/25.9 MB 3.6 MB/s eta 0:00:04
#    -------------------- ------------------- 13.3/25.9 MB 3.6 MB/s eta 0:00:04
#    -------------------- ------------------- 13.6/25.9 MB 3.6 MB/s eta 0:00:04
#    --------------------- ------------------ 13.9/25.9 MB 3.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 14.3/25.9 MB 4.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 14.6/25.9 MB 4.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 15.0/25.9 MB 4.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 15.1/25.9 MB 4.4 MB/s eta 0:00:03
#    ------------------------ --------------- 15.6/25.9 MB 4.5 MB/s eta 0:00:03
#    ------------------------ --------------- 16.0/25.9 MB 4.5 MB/s eta 0:00:03
#    ------------------------- -------------- 16.3/25.9 MB 4.6 MB/s eta 0:00:03
#    ------------------------- -------------- 16.7/25.9 MB 4.7 MB/s eta 0:00:02
#    -------------------------- ------------- 17.2/25.9 MB 4.8 MB/s eta 0:00:02
#    -------------------------- ------------- 17.5/25.9 MB 4.8 MB/s eta 0:00:02
#    --------------------------- ------------ 18.0/25.9 MB 4.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 18.5/25.9 MB 5.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.9/25.9 MB 4.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.1/25.9 MB 4.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.4/25.9 MB 5.0 MB/s eta 0:00:02
#    ------------------------------ --------- 20.0/25.9 MB 4.9 MB/s eta 0:00:02
#    ------------------------------- -------- 20.2/25.9 MB 4.9 MB/s eta 0:00:02
#    ------------------------------- -------- 20.5/25.9 MB 5.0 MB/s eta 0:00:02
#    -------------------------------- ------- 21.0/25.9 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 21.3/25.9 MB 5.0 MB/s eta 0:00:01
#    --------------------------------- ------ 21.6/25.9 MB 4.9 MB/s eta 0:00:01
#    --------------------------------- ------ 22.0/25.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.3/25.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.6/25.9 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.7/25.9 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.0/25.9 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 23.3/25.9 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 23.8/25.9 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 24.1/25.9 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 24.5/25.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 24.9/25.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 25.2/25.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  25.9/25.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  25.9/25.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 25.9/25.9 MB 4.7 MB/s eta 0:00:00
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading regex-2024.5.15-cp38-cp38-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/269.0 kB ? eta -:--:--
#    ---------------------------------------- 269.0/269.0 kB 8.3 MB/s eta 0:00:00
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading watchfiles-0.21.0-cp38-none-win_amd64.whl (279 kB)
#    ---------------------------------------- 0.0/279.9 kB ? eta -:--:--
#    --------------------------------------- 279.9/279.9 kB 16.9 MB/s eta 0:00:00
# Downloading websockets-12.0-cp38-cp38-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/125.0 kB ? eta -:--:--
#    ---------------------------------------- 125.0/125.0 kB ? eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading rich_click-1.8.2-py3-none-any.whl (34 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading Faker-25.2.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------- ----------------------- 0.7/1.8 MB 11.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 7.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 5.7 MB/s eta 0:00:00
# Installing collected packages: appdirs, websockets, watchdog, urllib3, ujson, tqdm, sniffio, shellingham, regex, PyYAML, python-dotenv, pydantic-core, pyarrow, patsy, mypy-extensions, multidict, msgspec, mdurl, idna, httptools, h11, fsspec, filelock, exceptiongroup, dynaconf, distro, click, charset-normalizer, certifi, annotated-types, uvicorn, typing-inspect, requests, pydantic, nltk, markdown-it-py, httpcore, faker, anyio, watchfiles, statsmodels, rich, polyfactory, iterative-telemetry, httpx, typer, rich-click, litestar, evidently
# Successfully installed PyYAML-6.0.1 annotated-types-0.6.0 anyio-4.3.0 appdirs-1.4.4 certifi-2024.2.2 charset-normalizer-3.3.2 click-8.1.7 distro-1.9.0 dynaconf-3.2.5 evidently-0.4.22 exceptiongroup-1.2.1 faker-25.2.0 filelock-3.14.0 fsspec-2024.5.0 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 idna-3.7 iterative-telemetry-0.0.8 litestar-2.8.3 markdown-it-py-3.0.0 mdurl-0.1.2 msgspec-0.18.6 multidict-6.0.5 mypy-extensions-1.0.0 nltk-3.8.1 patsy-0.5.6 polyfactory-2.16.0 pyarrow-16.1.0 pydantic-2.7.1 pydantic-core-2.18.2 python-dotenv-1.0.1 regex-2024.5.15 requests-2.31.0 rich-13.7.1 rich-click-1.8.2 shellingham-1.5.4 sniffio-1.3.1 statsmodels-0.14.1 tqdm-4.66.4 typer-0.12.3 typing-inspect-0.9.0 ujson-5.10.0 urllib3-2.2.1 uvicorn-0.29.0 watchdog-4.0.0 watchfiles-0.21.0 websockets-12.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script watchmedo.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dynaconf.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script faker.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script watchfiles.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script rich-click.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script litestar.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script evidently.exe is installed in 'c:\Users\HP\AppData\Local\anaconda3\envs\visa\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# Boston Data

# %%
import pandas as pd
import numpy as np

data_url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
boston_frame = pd.read_csv(data_url)

# %%
boston_frame.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# Data Drift Dashboard

# %%
boston_frame.shape
# Out:
# (506, 14)

# %%
boston_frame[:200]
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 195  0.01381  80.0   0.46     0  0.422  7.875  32.0  5.6484    4  255
# 196  0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 197  0.04666  80.0   1.52     0  0.404  7.107  36.6  7.3090    2  329
# 198  0.03768  80.0   1.52     0  0.404  7.274  38.3  7.3090    2  329
# 199  0.03150  95.0   1.47     0  0.403  6.975  15.3  7.6534    3  402
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 195     14.4  394.23   2.97  50.0
# 196     12.6  396.90   4.08  33.3
# 197     12.6  354.31   8.61  30.3
# 198     12.6  392.20   6.62  34.6
# 199     17.0  396.90   4.56  34.9
#
# [200 rows x 14 columns]

# %%
boston_frame[200:]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 200  0.01778  95.0   1.47     0  0.4030  7.135  13.9  7.6534    3  402
# 201  0.03445  82.5   2.03     0  0.4150  6.162  38.4  6.2700    2  348
# 202  0.02177  82.5   2.03     0  0.4150  7.610  15.7  6.2700    2  348
# 203  0.03510  95.0   2.68     0  0.4161  7.853  33.2  5.1180    4  224
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# ..       ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.5730  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.5730  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.5730  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.5730  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.5730  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 200     17.0  384.30   4.45  32.9
# 201     14.7  393.77   7.43  24.1
# 202     14.7  395.38   3.11  42.3
# 203     14.7  392.78   3.81  48.5
# 204     14.7  390.55   2.88  50.0
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [306 rows x 14 columns]

# %%
boston_data_drift_dashboard = Dashboard(tabs=[DataDriftTab()])
boston_data_drift_dashboard.calculate(boston_frame[:200], boston_frame[200:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 boston_data_drift_dashboard = Dashboard(tabs=[DataDriftTab()])
#       2 boston_data_drift_dashboard.calculate(boston_frame[:200], boston_frame[200:])
#
# NameError: name 'Dashboard' is not defined

# %%
boston_data_drift_dashboard.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 boston_data_drift_dashboard.show()
#
# NameError: name 'boston_data_drift_dashboard' is not defined

# %%
# boston_data_drift_dashboard.save('boston_data_drift_no_mapping.html')

# %% [markdown]
# Data Drift Dashboard with Column Mapping

# %%
boston_frame.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
column_mapping = {}

# column_mapping['target'] = 'target'
# column_mapping['prediction'] = None
# column_mapping['datetime'] = None

column_mapping['numerical_features'] = ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax',
                                        'ptratio', 'b', 'lstat']

column_mapping['categorical_features'] = ['chas', 'rad']

# %%
column_mapping
# Out:
# {'numerical_features': ['crim',
#   'zn',
#   'indus',
#   'nox',
#   'rm',
#   'age',
#   'dis',
#   'tax',
#   'ptratio',
#   'b',
#   'lstat'],
#  'categorical_features': ['chas', 'rad']}

# %%
boston_data_drift_dashboard.calculate(boston_frame[:200], boston_frame[200:], column_mapping = column_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 boston_data_drift_dashboard.calculate(boston_frame[:200], boston_frame[200:], column_mapping = column_mapping)
#
# NameError: name 'boston_data_drift_dashboard' is not defined

# %%
boston_data_drift_dashboard.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 boston_data_drift_dashboard.show()
#
# NameError: name 'boston_data_drift_dashboard' is not defined

# %% [markdown]
# Data Drift Profile

# %%
boston_data_drift_profile = Profile(sections=[DataDriftProfileSection()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 boston_data_drift_profile = Profile(sections=[DataDriftProfileSection()])
#
# NameError: name 'Profile' is not defined

# %%
boston_data_drift_profile.calculate(boston_frame[:200], boston_frame[200:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 boston_data_drift_profile.calculate(boston_frame[:200], boston_frame[200:])
#
# NameError: name 'boston_data_drift_profile' is not defined

# %%
boston_data_drift_profile.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 boston_data_drift_profile.json()
#
# NameError: name 'boston_data_drift_profile' is not defined
